# %%
import numpy as np

# %%
np.array([1, 2, 3, 4])
# Out:
# array([1, 2, 3, 4])

# %%
np.arange(1, 10, 2)
# Out:
# array([1, 3, 5, 7, 9])

# %%
np.linspace(0, 1, 5)
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %%
np.zeros((2, 3))
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
np.array([1, 2, 3, 4, 5, 6]).reshape(2, 3)
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
a = np.array([[1, 2], [3, 4]])
print(a.ndim)
print(a.shape)
print(a.size)
# Out:
# 2
# (2, 2)
# 4

# %%
np.array([1, 2, 3]) + np.array([4, 5, 6])
# Out:
# array([5, 7, 9])

# %%
np.sum([[1, 2, 3], [4, 5, 6]], axis=0)
# Out:
# array([5, 7, 9])

# %%
np.where(np.array([10, 20, 30, 40]) > 25, np.array([10, 20, 30, 40]), 0)
# Out:
# array([ 0,  0, 30, 40])

# %%
np.dot([[1, 2], [3, 4]], [[5, 6], [7, 8]])
# Out:
# array([[19, 22],
#        [43, 50]])
